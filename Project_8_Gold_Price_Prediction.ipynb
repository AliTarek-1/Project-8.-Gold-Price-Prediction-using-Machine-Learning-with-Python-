# %% [markdown]
# <a href="https://colab.research.google.com/github/AliTarek-1/Project-8.-Gold-Price-Prediction-using-Machine-Learning-with-Python-/blob/main/Project_8_Gold_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor , RandomForestClassifier

# %%
data=pd.read_csv("/content/gld_price_data.csv")

# %%
data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
data.shape
# Out:
# (2290, 6)

# %%
data['SPX'].value_counts()
# Out:
# SPX
# 1447.160034    2
# 2268.899902    2
# 2066.659912    2
# 2095.840088    2
# 2373.469971    2
#               ..
# 1278.359985    1
# 1267.640015    1
# 1265.420044    1
# 1287.869995    1
# 2725.780029    1
# Name: count, Length: 2277, dtype: int64

# %%
data['GLD'].value_counts()
# Out:
# GLD
# 115.940002    5
# 117.959999    4
# 122.209999    4
# 126.300003    4
# 124.589996    4
#              ..
# 147.179993    1
# 146.240005    1
# 145.729996    1
# 148.339996    1
# 122.543800    1
# Name: count, Length: 1930, dtype: int64

# %%
sns.countplot(x='SPX' , data=data)
# Out:
# <Axes: xlabel='SPX', ylabel='count'>

# %%
data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
sns.countplot(x='SPX' , hue='EUR/USD' , data=data)
# Out:
# <Axes: xlabel='SPX', ylabel='count'>

# %%
X=data.drop(['GLD'] , axis=1)
Y=data['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
X_train , X_test , Y_train , Y_test = train_test_split (X , Y , test_size=0.2 , random_state=2)

# %%
model=LinearRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
X_train_prediction=model.predict(X_train)
X_train_accuracy=r2_score(Y_train , X_train_prediction)
print("Accuracy of training is :" , X_train_accuracy)
# Out:
# Accuracy of training is : 0.8850695972446934

# %%
X_test_prediction = model.predict(X_test)
X_test_accuracy = r2_score(X_test_prediction , Y_test)
print("Accuracy of test is :" , X_test_accuracy)
# Out:
# Accuracy of test is : 0.8558146331362875

# %%
input=(1447.160034 ,78.370003,15.285 , 1.474491)

input_as_numpy_array= np.asarray(input)

input_reshaped= np.reshape(input_as_numpy_array , (1,-1))

prediction= model.predict(input_reshaped)

print(prediction)
# Out:
# [92.50844827]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model2=RandomForestRegressor()

# %%
model2.fit(X_train , Y_train)
# Out:
# RandomForestRegressor()

# %%
X_train_predict=model.predict(X_train)
X_train_accuracy2= r2_score(X_train_predict , Y_train)
print("Accuracy of training is :" , X_train_accuracy2)
# Out:
# Accuracy of training is : 0.8701453500232117

# %%
X_test_predict=model.predict(X_test)
X_test_accuracy2=r2_score(X_test_predict, Y_test)
print("Accuracy of test is :" , X_test_accuracy2)
# Out:
# Accuracy of test is : 0.8558146331362875

# %%
correlation=data.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation , cbar=True , square=True , fmt='.1f' , annot=True , annot_kws={'size':8} , cmap='Blues')
# Out:
# <Axes: >
